# %%
"""
File: briefTourOfData.ipynb
Description: This script offers a brief tour of the cleaned WRDS asset and liability 
             data used to build Table A1 and Figure A1. It loads the datasets and displays 
             key metrics to provide an initial overview of the data structure and quality.
Usage: Run the script to perform preliminary data exploration.
"""

# %%
import pandas as pd

# %% [markdown]
# Cleaned WRDS data used to build asset part of Table A1 & Figure A1

# %%
df = pd.read_csv('WRDSasset.csv')
df
# Out:
#       rssd9001  Total Asset     cash  security_total  security_treasury  \
# 0           37      80558.0   5977.0         50973.0              980.0
# 1          242      54405.0   4240.0         19178.0             3569.0
# 2          279     417610.0   7542.0        124817.0                0.0
# 3          354      57634.0   2769.0           964.0              238.0
# 4          457      72134.0   2668.0          1413.0             1413.0
# ...        ...          ...      ...             ...                ...
# 4719   5784921      34462.0   4647.0         29063.0             4207.0
# 4720   5787418      44619.0  13743.0          5855.0             5855.0
# 4721   5788705      51880.0  16335.0             0.0                0.0
# 4722   5805451      14592.0    971.0          7578.0             7578.0
# 4723   5805817      11912.0   5258.0          4995.0             4995.0
#
#       security_rmbs  security_cmbs  security_abs  security_other  Total_Loan  \
# ...

# %% [markdown]
# Cleaned WRDS data used to build liability part of Table A1 & Figure A1

# %%
df = pd.read_csv('WRDSliability.csv')
df
# Out:
#       rssd9001  Total Liability  Domestic Deposit  Insured Deposit  \
# 0           37          68999.0           68896.0              0.0
# 1          242          50968.0           48068.0              0.0
# 2          279         375787.0          310596.0          12000.0
# 3          354          50784.0           41401.0           4964.0
# 4          457          66040.0           58508.0              0.0
# ...        ...              ...               ...              ...
# 4719   5784921          21808.0           20644.0              0.0
# 4720   5787418          23819.0           22939.0              0.0
# 4721   5788705          24428.0           23007.0              0.0
# 4722   5805451           9054.0               0.0              0.0
# 4723   5805817           2211.0               0.0              0.0
#
#       Uninsured Deposit  Uninsured Time Deposits  \
# 0               68896.0                      957
# 1               48068.0                     4441
# ...

# %% [markdown]
# Treasury bond indexes of various maturity lengths from S&P and BlackRock (iShares) are used to calculate Table 1

# %%
df = pd.read_csv('Tres.csv')
df
# Out:
#             date  iShares 0-1  iShares 1-3  iShares 7-10  iShares 10-20  \
# 0     2019-03-08    99.271431    95.389023     77.822388     117.990493
# 1     2019-03-09    99.271431    95.389023     77.822388     117.990493
# 2     2019-03-10    99.271431    95.389023     77.822388     117.990493
# 3     2019-03-11    99.291252    95.318429     77.804558     117.821891
# 4     2019-03-12    99.291252    95.574227     77.831231     118.310699
# ...          ...          ...          ...           ...            ...
# 1816  2024-02-26   109.080002    93.316102     81.628930     104.106697
# 1817  2024-02-27   109.080002    93.114144     81.628930     103.608802
# 1818  2024-02-28   109.099998    93.441117     81.705597     104.068367
# 1819  2024-02-29   109.180000    93.623894     81.753518     104.614143
# 1820  2024-03-01   109.180000    93.623894     81.753518     104.614143
#
#       iShares 20+  sp 1-3  sp 3-5  sp 7-10
# 0      108.613502  322.20  451.01   601.05
# ...

# %% [markdown]
# Single treasury bond index is used to further calculate Table 1

# %%
df = pd.read_csv('TresIndex.csv')
df
# Out:
#            date  S&P U.S. Treasury Bond Index
# 0    2021-02-26                        472.27
# 1    2021-03-01                        471.27
# 2    2021-03-02                        471.64
# 3    2021-03-03                        470.10
# 4    2021-03-04                        469.03
# ..          ...                           ...
# 746  2024-02-20                        433.54
# 747  2024-02-21                        432.54
# 748  2024-02-22                        432.60
# 749  2024-02-23                        434.01
# 750  2024-02-26                        433.62
#
# [751 rows x 2 columns]

# %% [markdown]
# Single mortgage backed bond index is used to further calculate Table 1

# %%
df = pd.read_csv('MBS.csv')
df
# Out:
#             Date  Adj Close       High        Low       Open   Volume
# 0     2019-03-11  89.949745  89.949745  89.881347  89.941200   419300
# 1     2019-03-12  90.120743  90.154945  90.001038  90.001038   477300
# 2     2019-03-13  90.146400  90.172050  90.095100  90.095100   471700
# 3     2019-03-14  90.086548  90.189154  90.069443  90.137848   639400
# 4     2019-03-15  90.240448  90.283196  90.137841  90.180596  1218600
# ...          ...        ...        ...        ...        ...      ...
# 1253  2024-03-01  88.480980  88.529039  87.827416  88.058091  1981200
# 1254  2024-03-04  88.211861  88.375250  88.096531  88.259920  3726100
# 1255  2024-03-05  88.855827  88.913500  88.509822  88.615547  2120000
# 1256  2024-03-06  88.999985  89.211433  88.913487  89.048044  4811200
# 1257  2024-03-07  89.163383  89.240275  88.942329  89.240275  2298600
#
# [1258 rows x 6 columns]
